# %%
# This cell imports all the libraries required in the lab.
# pandas is used for working with tabular data.
# numpy is used for numerical operations.
# sklearn is used for text vectorization and similarity calculation.

import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# This line improves the display of tables in notebooks.
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 1000)

print("Libraries imported successfully.")

# %%
# This cell creates a synthetic dataset of 20 candidates.
# Each row represents one candidate.
# The fields are designed to simulate basic recruitment information.

data = [
    {"candidate_id": 1, "name": "Aarav", "skills": "python sql machine learning excel", "experience_years": 3, "education": "B.Tech", "certifications": 2},
    {"candidate_id": 2, "name": "Diya", "skills": "excel communication recruitment onboarding", "experience_years": 4, "education": "MBA HR", "certifications": 1},
    {"candidate_id": 3, "name": "Kabir", "skills": "python pandas data analysis sql tableau", "experience_years": 2, "education": "B.Sc", "certifications": 3},
    {"candidate_id": 4, "name": "Ishita", "skills": "java sql spring communication teamwork", "experience_years": 5, "education": "B.Tech", "certifications": 2},
    {"candidate_id": 5, "name": "Vivaan", "skills": "python sql deep learning nlp bert", "experience_years": 6, "education": "M.Tech", "certifications": 4},
    {"candidate_id": 6, "name": "Anaya", "skills": "recruitment sourcing interview screening communication", "experience_years": 3, "education": "MBA HR", "certifications": 2},
    {"candidate_id": 7, "name": "Reyansh", "skills": "python sql power bi excel statistics", "experience_years": 4, "education": "B.Tech", "certifications": 2},
    {"candidate_id": 8, "name": "Myra", "skills": "machine learning python data visualization tableau", "experience_years": 2, "education": "M.Sc", "certifications": 3},
    {"candidate_id": 9, "name": "Arjun", "skills": "manual testing selenium jira communication", "experience_years": 5, "education": "BCA", "certifications": 1},
    {"candidate_id": 10, "name": "Siya", "skills": "python sql ml nlp communication teamwork", "experience_years": 3, "education": "MCA", "certifications": 3},
    {"candidate_id": 11, "name": "Krish", "skills": "excel sql reporting dashboard power bi", "experience_years": 2, "education": "B.Com", "certifications": 2},
    {"candidate_id": 12, "name": "Aadhya", "skills": "python r statistics machine learning", "experience_years": 4, "education": "M.Stat", "certifications": 3},
    {"candidate_id": 13, "name": "Advik", "skills": "project management agile scrum communication", "experience_years": 6, "education": "MBA", "certifications": 2},
    {"candidate_id": 14, "name": "Kiara", "skills": "python sql data analysis recruitment hr analytics", "experience_years": 5, "education": "MBA HR", "certifications": 4},
    {"candidate_id": 15, "name": "Atharv", "skills": "c++ algorithms data structures problem solving", "experience_years": 1, "education": "B.Tech", "certifications": 1},
    {"candidate_id": 16, "name": "Navya", "skills": "python sql tableau power bi communication", "experience_years": 3, "education": "BBA", "certifications": 2},
    {"candidate_id": 17, "name": "Rudra", "skills": "nlp bert transformers python machine learning", "experience_years": 5, "education": "M.Tech", "certifications": 4},
    {"candidate_id": 18, "name": "Sara", "skills": "recruitment analytics excel communication hr operations", "experience_years": 4, "education": "MBA HR", "certifications": 2},
    {"candidate_id": 19, "name": "Vihaan", "skills": "python sql statistics data cleaning pandas", "experience_years": 2, "education": "B.Sc", "certifications": 2},
    {"candidate_id": 20, "name": "Meera", "skills": "python machine learning sql communication dashboards", "experience_years": 4, "education": "MCA", "certifications": 3}
]

df = pd.DataFrame(data)

print("Synthetic dataset created successfully.")
df
# Out:
# Synthetic dataset created successfully.
#     candidate_id     name                                             skills  \
# 0              1    Aarav                  python sql machine learning excel
# 1              2     Diya         excel communication recruitment onboarding
# 2              3    Kabir            python pandas data analysis sql tableau
# 3              4   Ishita             java sql spring communication teamwork
# 4              5   Vivaan                  python sql deep learning nlp bert
# 5              6    Anaya  recruitment sourcing interview screening commu...
# 6              7  Reyansh               python sql power bi excel statistics
# 7              8     Myra  machine learning python data visualization tab...
# 8              9    Arjun         manual testing selenium jira communication
# 9             10     Siya           python sql ml nlp communication teamwork
# 10            11    Krish             excel sql reporting dashboard power bi
# 11            12   Aadhya               python r statistics machine learning
# 12            13    Advik       project management agile scrum communication
# 13            14    Kiara  python sql data analysis recruitment hr analytics
# 14            15   Atharv     c++ algorithms data structures problem solving
# 15            16    Navya          python sql tableau power bi communication
# 16            17    Rudra      nlp bert transformers python machine learning
# 17            18     Sara  recruitment analytics excel communication hr o...
# 18            19   Vihaan         python sql statistics data cleaning pandas
# 19            20    Meera  python machine learning sql communication dash...
#
#     experience_years education  certifications
# 0                  3    B.Tech               2
# 1                  4    MBA HR               1
# 2                  2      B.Sc               3
# 3                  5    B.Tech               2
# 4                  6    M.Tech               4
# 5                  3    MBA HR               2
# 6                  4    B.Tech               2
# 7                  2      M.Sc               3
# 8                  5       BCA               1
# 9                  3       MCA               3
# 10                 2     B.Com               2
# 11                 4    M.Stat               3
# 12                 6       MBA               2
# 13                 5    MBA HR               4
# 14                 1    B.Tech               1
# 15                 3       BBA               2
# 16                 5    M.Tech               4
# 17                 4    MBA HR               2
# 18                 2      B.Sc               2
# 19                 4       MCA               3

# %%
# This cell checks the shape of the dataset and displays all column names.
# shape gives the total number of rows and columns.
# columns gives the names of all variables.

import pandas as pd

df = pd.DataFrame(data)

print("Dataset shape:", df.shape)
print("Column names:", list(df.columns))
# Out:
# Dataset shape: (20, 6)
# Column names: ['candidate_id', 'name', 'skills', 'experience_years', 'education', 'certifications']

# %%
# This cell displays the first 5 rows of the dataset.
# head() is useful for quickly checking whether the data looks correct.

df.head()
# Out:
#    candidate_id    name                                      skills  \
# 0             1   Aarav           python sql machine learning excel
# 1             2    Diya  excel communication recruitment onboarding
# 2             3   Kabir     python pandas data analysis sql tableau
# 3             4  Ishita      java sql spring communication teamwork
# 4             5  Vivaan           python sql deep learning nlp bert
#
#    experience_years education  certifications
# 0                 3    B.Tech               2
# 1                 4    MBA HR               1
# 2                 2      B.Sc               3
# 3                 5    B.Tech               2
# 4                 6    M.Tech               4

# %%
# This cell defines the target job description.
# In a real recruitment system, this text would come from an actual job posting.
# We keep it short and relevant for learning purposes.

job_description = "python sql machine learning nlp communication dashboards recruitment analytics"

print("Job Description:")
print(job_description)
# Out:
# Job Description:
# python sql machine learning nlp communication dashboards recruitment analytics

# %%
# This cell combines the job description and all candidate skills into one list.
# Then it converts the text into a TF-IDF matrix.
# The matrix is a numerical representation of the text.

from sklearn.feature_extraction.text import TfidfVectorizer

documents = [job_description] + df["skills"].tolist()

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)

print("TF-IDF matrix shape:", tfidf_matrix.shape)
# Out:
# TF-IDF matrix shape: (21, 46)

# %%
# This cell calculates cosine similarity between:
# 1. the job description vector
# 2. each candidate skill vector
#
# The result is stored as a similarity score for each candidate.

from sklearn.metrics.pairwise import cosine_similarity

job_vector = tfidf_matrix[0:1]
candidate_vectors = tfidf_matrix[1:]

similarity_scores = cosine_similarity(job_vector, candidate_vectors).flatten()

df["similarity_score"] = similarity_scores

print("Cosine similarity scores calculated successfully.")
df[["candidate_id", "name", "skills", "similarity_score"]]
# Out:
# Cosine similarity scores calculated successfully.
#     candidate_id     name                                             skills  \
# 0              1    Aarav                  python sql machine learning excel
# 1              2     Diya         excel communication recruitment onboarding
# 2              3    Kabir            python pandas data analysis sql tableau
# 3              4   Ishita             java sql spring communication teamwork
# 4              5   Vivaan                  python sql deep learning nlp bert
# 5              6    Anaya  recruitment sourcing interview screening commu...
# 6              7  Reyansh               python sql power bi excel statistics
# 7              8     Myra  machine learning python data visualization tab...
# 8              9    Arjun         manual testing selenium jira communication
# 9             10     Siya           python sql ml nlp communication teamwork
# 10            11    Krish             excel sql reporting dashboard power bi
# 11            12   Aadhya               python r statistics machine learning
# 12            13    Advik       project management agile scrum communication
# 13            14    Kiara  python sql data analysis recruitment hr analytics
# 14            15   Atharv     c++ algorithms data structures problem solving
# 15            16    Navya          python sql tableau power bi communication
# 16            17    Rudra      nlp bert transformers python machine learning
# 17            18     Sara  recruitment analytics excel communication hr o...
# 18            19   Vihaan         python sql statistics data cleaning pandas
# 19            20    Meera  python machine learning sql communication dash...
#
#     similarity_score
# 0           0.461985
# 1           0.246840
# 2           0.113584
# 3           0.128840
# 4           0.373774
# 5           0.188620
# 6           0.119317
# 7           0.275516
# 8           0.061943
# 9           0.349575
# 10          0.052342
# 11          0.382899
# 12          0.061943
# 13          0.406514
# 14          0.000000
# 15          0.204367
# 16          0.418469
# 17          0.364453
# 18          0.109594
# 19          0.755230

# %%
# This cell normalizes experience and certification values.
# Normalization means converting values into a common range.
# Here we divide each value by the maximum value in its column.

df["experience_score"] = df["experience_years"] / df["experience_years"].max()
df["certification_score"] = df["certifications"] / df["certifications"].max()

df[["name", "experience_years", "experience_score", "certifications", "certification_score"]]
# Out:
#        name  experience_years  experience_score  certifications  \
# 0     Aarav                 3          0.500000               2
# 1      Diya                 4          0.666667               1
# 2     Kabir                 2          0.333333               3
# 3    Ishita                 5          0.833333               2
# 4    Vivaan                 6          1.000000               4
# 5     Anaya                 3          0.500000               2
# 6   Reyansh                 4          0.666667               2
# 7      Myra                 2          0.333333               3
# 8     Arjun                 5          0.833333               1
# 9      Siya                 3          0.500000               3
# 10    Krish                 2          0.333333               2
# 11   Aadhya                 4          0.666667               3
# 12    Advik                 6          1.000000               2
# 13    Kiara                 5          0.833333               4
# 14   Atharv                 1          0.166667               1
# 15    Navya                 3          0.500000               2
# 16    Rudra                 5          0.833333               4
# 17     Sara                 4          0.666667               2
# 18   Vihaan                 2          0.333333               2
# 19    Meera                 4          0.666667               3
#
#     certification_score
# 0                  0.50
# 1                  0.25
# 2                  0.75
# 3                  0.50
# 4                  1.00
# 5                  0.50
# 6                  0.50
# 7                  0.75
# 8                  0.25
# 9                  0.75
# 10                 0.50
# 11                 0.75
# 12                 0.50
# 13                 1.00
# 14                 0.25
# 15                 0.50
# 16                 1.00
# 17                 0.50
# 18                 0.50
# 19                 0.75

# %%
# This cell maps education categories into numerical scores.
# Higher values are assigned to higher or more specialized qualifications.
# This is just a teaching example, not a universal hiring rule.

education_map = {
    "B.Com": 0.50,
    "BBA": 0.55,
    "BCA": 0.55,
    "B.Sc": 0.60,
    "B.Tech": 0.70,
    "MBA": 0.75,
    "MBA HR": 0.80,
    "MCA": 0.80,
    "M.Sc": 0.80,
    "M.Tech": 0.90,
    "M.Stat": 0.90
}

df["education_score"] = df["education"].map(education_map)

df[["name", "education", "education_score"]]
# Out:
#        name education  education_score
# 0     Aarav    B.Tech             0.70
# 1      Diya    MBA HR             0.80
# 2     Kabir      B.Sc             0.60
# 3    Ishita    B.Tech             0.70
# 4    Vivaan    M.Tech             0.90
# 5     Anaya    MBA HR             0.80
# 6   Reyansh    B.Tech             0.70
# 7      Myra      M.Sc             0.80
# 8     Arjun       BCA             0.55
# 9      Siya       MCA             0.80
# 10    Krish     B.Com             0.50
# 11   Aadhya    M.Stat             0.90
# 12    Advik       MBA             0.75
# 13    Kiara    MBA HR             0.80
# 14   Atharv    B.Tech             0.70
# 15    Navya       BBA             0.55
# 16    Rudra    M.Tech             0.90
# 17     Sara    MBA HR             0.80
# 18   Vihaan      B.Sc             0.60
# 19    Meera       MCA             0.80

# %%
# This cell creates the final weighted score for each candidate.
# It combines text similarity, experience, education, and certifications.

df["final_score"] = (
    0.50 * df["similarity_score"] +
    0.25 * df["experience_score"] +
    0.15 * df["education_score"] +
    0.10 * df["certification_score"]
)

df[["name", "similarity_score", "experience_score", "education_score", "certification_score", "final_score"]]
# Out:
#        name  similarity_score  experience_score  education_score  \
# 0     Aarav          0.461985          0.500000             0.70
# 1      Diya          0.246840          0.666667             0.80
# 2     Kabir          0.113584          0.333333             0.60
# 3    Ishita          0.128840          0.833333             0.70
# 4    Vivaan          0.373774          1.000000             0.90
# 5     Anaya          0.188620          0.500000             0.80
# 6   Reyansh          0.119317          0.666667             0.70
# 7      Myra          0.275516          0.333333             0.80
# 8     Arjun          0.061943          0.833333             0.55
# 9      Siya          0.349575          0.500000             0.80
# 10    Krish          0.052342          0.333333             0.50
# 11   Aadhya          0.382899          0.666667             0.90
# 12    Advik          0.061943          1.000000             0.75
# 13    Kiara          0.406514          0.833333             0.80
# 14   Atharv          0.000000          0.166667             0.70
# 15    Navya          0.204367          0.500000             0.55
# 16    Rudra          0.418469          0.833333             0.90
# 17     Sara          0.364453          0.666667             0.80
# 18   Vihaan          0.109594          0.333333             0.60
# 19    Meera          0.755230          0.666667             0.80
#
#     certification_score  final_score
# 0                  0.50     0.510992
# 1                  0.25     0.435087
# 2                  0.75     0.305125
# 3                  0.50     0.427753
# 4                  1.00     0.671887
# 5                  0.50     0.389310
# 6                  0.50     0.381325
# 7                  0.75     0.416091
# 8                  0.25     0.346805
# 9                  0.75     0.494788
# 10                 0.50     0.234504
# 11                 0.75     0.568116
# 12                 0.50     0.443472
# 13                 1.00     0.631590
# 14                 0.25     0.171667
# 15                 0.50     0.359683
# 16                 1.00     0.652568
# 17                 0.50     0.518893
# 18                 0.50     0.278130
# 19                 0.75     0.739282

# %%
# This cell sorts candidates in descending order based on the final score.
# The highest-scoring candidate appears first.

ranked_df = df.sort_values(by="final_score", ascending=False).reset_index(drop=True)

ranked_df[["candidate_id", "name", "skills", "experience_years", "education", "certifications", "final_score"]]
# Out:
#     candidate_id     name                                             skills  \
# 0             20    Meera  python machine learning sql communication dash...
# 1              5   Vivaan                  python sql deep learning nlp bert
# 2             17    Rudra      nlp bert transformers python machine learning
# 3             14    Kiara  python sql data analysis recruitment hr analytics
# 4             12   Aadhya               python r statistics machine learning
# 5             18     Sara  recruitment analytics excel communication hr o...
# 6              1    Aarav                  python sql machine learning excel
# 7             10     Siya           python sql ml nlp communication teamwork
# 8             13    Advik       project management agile scrum communication
# 9              2     Diya         excel communication recruitment onboarding
# 10             4   Ishita             java sql spring communication teamwork
# 11             8     Myra  machine learning python data visualization tab...
# 12             6    Anaya  recruitment sourcing interview screening commu...
# 13             7  Reyansh               python sql power bi excel statistics
# 14            16    Navya          python sql tableau power bi communication
# 15             9    Arjun         manual testing selenium jira communication
# 16             3    Kabir            python pandas data analysis sql tableau
# 17            19   Vihaan         python sql statistics data cleaning pandas
# 18            11    Krish             excel sql reporting dashboard power bi
# 19            15   Atharv     c++ algorithms data structures problem solving
#
#     experience_years education  certifications  final_score
# 0                  4       MCA               3     0.739282
# 1                  6    M.Tech               4     0.671887
# 2                  5    M.Tech               4     0.652568
# 3                  5    MBA HR               4     0.631590
# 4                  4    M.Stat               3     0.568116
# 5                  4    MBA HR               2     0.518893
# 6                  3    B.Tech               2     0.510992
# 7                  3       MCA               3     0.494788
# 8                  6       MBA               2     0.443472
# 9                  4    MBA HR               1     0.435087
# 10                 5    B.Tech               2     0.427753
# 11                 2      M.Sc               3     0.416091
# 12                 3    MBA HR               2     0.389310
# 13                 4    B.Tech               2     0.381325
# 14                 3       BBA               2     0.359683
# 15                 5       BCA               1     0.346805
# 16                 2      B.Sc               3     0.305125
# 17                 2      B.Sc               2     0.278130
# 18                 2     B.Com               2     0.234504
# 19                 1    B.Tech               1     0.171667

# %%
# This cell extracts the top 5 candidates from the ranked dataset.
# These candidates are considered the strongest matches according to the model.

top_5 = ranked_df.head(5)

top_5[["candidate_id", "name", "skills", "experience_years", "education", "certifications", "final_score"]]
# Out:
#    candidate_id    name                                             skills  \
# 0            20   Meera  python machine learning sql communication dash...
# 1             5  Vivaan                  python sql deep learning nlp bert
# 2            17   Rudra      nlp bert transformers python machine learning
# 3            14   Kiara  python sql data analysis recruitment hr analytics
# 4            12  Aadhya               python r statistics machine learning
#
#    experience_years education  certifications  final_score
# 0                 4       MCA               3     0.739282
# 1                 6    M.Tech               4     0.671887
# 2                 5    M.Tech               4     0.652568
# 3                 5    MBA HR               4     0.631590
# 4                 4    M.Stat               3     0.568116

# %%
# This cell converts final numeric scores into simple decision labels.
# This makes the result easier to interpret from an HR point of view.

def label_candidate(score):
    if score >= 0.65:
        return "Strong Match"
    elif score >= 0.50:
        return "Moderate Match"
    else:
        return "Low Match"

ranked_df["recommendation"] = ranked_df["final_score"].apply(label_candidate)

ranked_df[["candidate_id", "name", "final_score", "recommendation"]]
# Out:
#     candidate_id     name  final_score  recommendation
# 0             20    Meera     0.739282    Strong Match
# 1              5   Vivaan     0.671887    Strong Match
# 2             17    Rudra     0.652568    Strong Match
# 3             14    Kiara     0.631590  Moderate Match
# 4             12   Aadhya     0.568116  Moderate Match
# 5             18     Sara     0.518893  Moderate Match
# 6              1    Aarav     0.510992  Moderate Match
# 7             10     Siya     0.494788       Low Match
# 8             13    Advik     0.443472       Low Match
# 9              2     Diya     0.435087       Low Match
# 10             4   Ishita     0.427753       Low Match
# 11             8     Myra     0.416091       Low Match
# 12             6    Anaya     0.389310       Low Match
# 13             7  Reyansh     0.381325       Low Match
# 14            16    Navya     0.359683       Low Match
# 15             9    Arjun     0.346805       Low Match
# 16             3    Kabir     0.305125       Low Match
# 17            19   Vihaan     0.278130       Low Match
# 18            11    Krish     0.234504       Low Match
# 19            15   Atharv     0.171667       Low Match

# %%
# This cell creates the final structured output table.
# It includes the original candidate details and all calculated scores.

final_output = ranked_df[[
    "candidate_id",
    "name",
    "skills",
    "experience_years",
    "education",
    "certifications",
    "similarity_score",
    "experience_score",
    "education_score",
    "certification_score",
    "final_score",
    "recommendation"
]]

final_output
# Out:
#     candidate_id     name                                             skills  \
# 0             20    Meera  python machine learning sql communication dash...
# 1              5   Vivaan                  python sql deep learning nlp bert
# 2             17    Rudra      nlp bert transformers python machine learning
# 3             14    Kiara  python sql data analysis recruitment hr analytics
# 4             12   Aadhya               python r statistics machine learning
# 5             18     Sara  recruitment analytics excel communication hr o...
# 6              1    Aarav                  python sql machine learning excel
# 7             10     Siya           python sql ml nlp communication teamwork
# 8             13    Advik       project management agile scrum communication
# 9              2     Diya         excel communication recruitment onboarding
# 10             4   Ishita             java sql spring communication teamwork
# 11             8     Myra  machine learning python data visualization tab...
# 12             6    Anaya  recruitment sourcing interview screening commu...
# 13             7  Reyansh               python sql power bi excel statistics
# 14            16    Navya          python sql tableau power bi communication
# 15             9    Arjun         manual testing selenium jira communication
# 16             3    Kabir            python pandas data analysis sql tableau
# 17            19   Vihaan         python sql statistics data cleaning pandas
# 18            11    Krish             excel sql reporting dashboard power bi
# 19            15   Atharv     c++ algorithms data structures problem solving
#
#     experience_years education  certifications  similarity_score  \
# 0                  4       MCA               3          0.755230
# 1                  6    M.Tech               4          0.373774
# 2                  5    M.Tech               4          0.418469
# 3                  5    MBA HR               4          0.406514
# 4                  4    M.Stat               3          0.382899
# 5                  4    MBA HR               2          0.364453
# 6                  3    B.Tech               2          0.461985
# 7                  3       MCA               3          0.349575
# 8                  6       MBA               2          0.061943
# 9                  4    MBA HR               1          0.246840
# 10                 5    B.Tech               2          0.128840
# 11                 2      M.Sc               3          0.275516
# 12                 3    MBA HR               2          0.188620
# 13                 4    B.Tech               2          0.119317
# 14                 3       BBA               2          0.204367
# 15                 5       BCA               1          0.061943
# 16                 2      B.Sc               3          0.113584
# 17                 2      B.Sc               2          0.109594
# 18                 2     B.Com               2          0.052342
# 19                 1    B.Tech               1          0.000000
#
#     experience_score  education_score  certification_score  final_score  \
# 0           0.666667             0.80                 0.75     0.739282
# 1           1.000000             0.90                 1.00     0.671887
# 2           0.833333             0.90                 1.00     0.652568
# 3           0.833333             0.80                 1.00     0.631590
# 4           0.666667             0.90                 0.75     0.568116
# 5           0.666667             0.80                 0.50     0.518893
# 6           0.500000             0.70                 0.50     0.510992
# 7           0.500000             0.80                 0.75     0.494788
# 8           1.000000             0.75                 0.50     0.443472
# 9           0.666667             0.80                 0.25     0.435087
# 10          0.833333             0.70                 0.50     0.427753
# 11          0.333333             0.80                 0.75     0.416091
# 12          0.500000             0.80                 0.50     0.389310
# 13          0.666667             0.70                 0.50     0.381325
# 14          0.500000             0.55                 0.50     0.359683
# 15          0.833333             0.55                 0.25     0.346805
# 16          0.333333             0.60                 0.75     0.305125
# 17          0.333333             0.60                 0.50     0.278130
# 18          0.333333             0.50                 0.50     0.234504
# 19          0.166667             0.70                 0.25     0.171667
#
#     recommendation
# 0     Strong Match
# 1     Strong Match
# 2     Strong Match
# 3   Moderate Match
# 4   Moderate Match
# 5   Moderate Match
# 6   Moderate Match
# 7        Low Match
# 8        Low Match
# 9        Low Match
# 10       Low Match
# 11       Low Match
# 12       Low Match
# 13       Low Match
# 14       Low Match
# 15       Low Match
# 16       Low Match
# 17       Low Match
# 18       Low Match
# 19       Low Match

# %%
# This cell saves the final recruitment output into a CSV file.
# Students can download the file after running the cell.

final_output.to_csv("recruitment_screening_output.csv", index=False)

print("File saved successfully as recruitment_screening_output.csv")
# Out:
# File saved successfully as recruitment_screening_output.csv
